# %% [markdown]
# # Prepare colab workspace

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set current working directory to folder with the data
folder_name = "roof-angle-predictor"
# %mkdir -p /content/drive/MyDrive/{folder_name}
# %cd /content/drive/MyDrive/{folder_name}
# Out:
# /content/drive/MyDrive/roof-angle-predictor

# %% [markdown]
# # Explorative analysis

# %%
import pandas as pd
import matplotlib

# %%
df = pd.read_csv("hamburg_data_clean.csv")
df
# Out:
#                   gmlid  zipCode     city              street houseNumber  \
# 0      DEHHALKAn0000uVm    21039  Hamburg  Curslacker Heerweg           1
# 1      DEHHALKAn0000uW4    21039  Hamburg  Curslacker Heerweg           1
# 2      DEHHALKAn0000v1F    21039  Hamburg  Curslacker Heerweg          10
# 3      DEHHALKAn0000v20    21039  Hamburg  Curslacker Heerweg          10
# 4      DEHHALKAn0000vaC    21039  Hamburg  Curslacker Heerweg         104
# ...                 ...      ...      ...                 ...         ...
# 30851  DEHHALKAP0001IFp    22547  Hamburg        Elbgaustraße        222a
# 30852  DEHHALKAV0000VE0    22523  Hamburg              Astweg          33
# 30853  DEHHALKAV0000WO8    22523  Hamburg         Niekampsweg         22b
# 30854  DEHHALKAV0000Xt8    22523  Hamburg           Wildacker          24
# 30855  DEHHALKAV0000YFw    22523  Hamburg     Reemstückenkamp         28c
#
#        buildingFootprintArea  storeysEstimated  grossFloorSpace  \
# ...
